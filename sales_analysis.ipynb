# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('sales_data-1.csv')
df.head()
# Out:
#          Date     Product     Category Region  Quantity  Price Salesperson
# 0  2024-01-05      Laptop  Electronics  North         3  55000  Ravi Kumar
# 1  2024-01-06       Mouse  Electronics  South        10    500    Anitha S
# 2  2024-01-07  Desk Chair    Furniture   East         5   3500  Ravi Kumar
# 3  2024-01-08    Notebook   Stationery   West        50     20     Priya M
# 4  2024-01-09     Monitor  Electronics  North         4  12000    Anitha S

# %%
print(df.shape)
print(df.info())
# Out:
# (30, 7)
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         30 non-null     str
#  1   Product      30 non-null     str
#  2   Category     30 non-null     str
#  3   Region       30 non-null     str
#  4   Quantity     30 non-null     int64
#  5   Price        30 non-null     int64
#  6   Salesperson  30 non-null     str
# dtypes: int64(2), str(5)
# memory usage: 1.8 KB
# None

# %%
df['Total_Sales'] = df['Quantity'] * df['Price']
df.head(10)
# Out:
#          Date       Product     Category Region  Quantity  Price Salesperson  \
# 0  2024-01-05        Laptop  Electronics  North         3  55000  Ravi Kumar
# 1  2024-01-06         Mouse  Electronics  South        10    500    Anitha S
# 2  2024-01-07    Desk Chair    Furniture   East         5   3500  Ravi Kumar
# 3  2024-01-08      Notebook   Stationery   West        50     20     Priya M
# 4  2024-01-09       Monitor  Electronics  North         4  12000    Anitha S
# 5  2024-01-10           Pen   Stationery  South       100     10     Priya M
# 6  2024-01-11     Bookshelf    Furniture   East         2   4500  Ravi Kumar
# 7  2024-01-12      Keyboard  Electronics   West         8   1500    Anitha S
# 8  2024-01-13        Laptop  Electronics  North         2  55000  Ravi Kumar
# 9  2024-01-14  Office Table    Furniture  South         3   8000     Priya M
#
#    Total_Sales
# 0       165000
# 1         5000
# 2        17500
# 3         1000
# 4        48000
# 5         1000
# 6         9000
# 7        12000
# 8       110000
# 9        24000

# %%
category_sales = df.groupby('Category')['Total_Sales'].sum()
print(category_sales)

category_sales.plot(kind='bar')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()
# Out:
# Category
# Electronics    880500
# Furniture      157000
# Stationery       6900
# Name: Total_Sales, dtype: int64

# %%
region_sales = df.groupby('Region')['Total_Sales'].sum()
print(region_sales)

region_sales.plot(kind='bar', color='orange')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()
# Out:
# Region
# East     288700
# North    417200
# South    227100
# West     111400
# Name: Total_Sales, dtype: int64
